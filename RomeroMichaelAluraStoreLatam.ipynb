# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingresos = {
    "tienda 1": tienda1["Precio"].sum(),
    "tienda 2": tienda2["Precio"].sum(),
    "tienda 3": tienda3["Precio"].sum(),
    "tienda 4": tienda4["Precio"].sum()
}

# %%
df_ingresos = pd.DataFrame(list(ingresos.items()), columns=["Tienda", "Ingreso Total"])
print(df_ingresos)
# Out:
#      Tienda  Ingreso Total
# 0  tienda 1   1.150880e+09
# 1  tienda 2   1.116344e+09
# 2  tienda 3   1.098020e+09
# 3  tienda 4   1.038376e+09

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_t1 = tienda1.groupby("Categoría del Producto")["Producto"].count().sort_values(ascending=False)
ventas_t2 = tienda2.groupby("Categoría del Producto")["Producto"].count().sort_values(ascending=False)
ventas_t3 = tienda3.groupby("Categoría del Producto")["Producto"].count().sort_values(ascending=False)
ventas_t4 = tienda4.groupby("Categoría del Producto")["Producto"].count().sort_values(ascending=False)

# %%
print("Ventas por categoría - Tienda 1")
print(ventas_t1, "\n")

print("Ventas por categoría - Tienda 2")
print(ventas_t2, "\n")

print("Ventas por categoría - Tienda 3")
print(ventas_t3, "\n")

print("Ventas por categoría - Tienda 4")
print(ventas_t4, "\n")
# Out:
# Ventas por categoría - Tienda 1
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: Producto, dtype: int64
#
# Ventas por categoría - Tienda 2
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: Producto, dtype: int64
#
# Ventas por categoría - Tienda 3
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calif_t1 = tienda["Calificación"].mean()
calif_t2 = tienda2["Calificación"].mean()
calif_t3 = tienda3["Calificación"].mean()
calif_t4 = tienda4["Calificación"].mean()

# %%
print("Calificación promedio - Tienda 1:", round(calif_t1, 2))
print("Calificación promedio - Tienda 2:", round(calif_t2, 2))
print("Calificación promedio - Tienda 3:", round(calif_t3, 2))
print("Calificación promedio - Tienda 4:", round(calif_t4, 2))
# Out:
# Calificación promedio - Tienda 1: 3.98
# Calificación promedio - Tienda 2: 4.04
# Calificación promedio - Tienda 3: 4.05
# Calificación promedio - Tienda 4: 4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Tienda 1
ventas_prod_t1 = tienda.groupby("Producto")["Producto"].count().sort_values(ascending=False)
print("Tienda 1 - Más vendidos:")
print(ventas_prod_t1.head(), "\n")
print("Tienda 1 - Menos vendidos:")
print(ventas_prod_t1.tail(), "\n")

# Tienda 2
ventas_prod_t2 = tienda2.groupby("Producto")["Producto"].count().sort_values(ascending=False)
print("Tienda 2 - Más vendidos:")
print(ventas_prod_t2.head(), "\n")
print("Tienda 2 - Menos vendidos:")
print(ventas_prod_t2.tail(), "\n")

# Tienda 3
ventas_prod_t3 = tienda3.groupby("Producto")["Producto"].count().sort_values(ascending=False)
print("Tienda 3 - Más vendidos:")
print(ventas_prod_t3.head(), "\n")
print("Tienda 3 - Menos vendidos:")
print(ventas_prod_t3.tail(), "\n")

# Tienda 4
ventas_prod_t4 = tienda4.groupby("Producto")["Producto"].count().sort_values(ascending=False)
print("Tienda 4 - Más vendidos:")
print(ventas_prod_t4.head(), "\n")
print("Tienda 4 - Menos vendidos:")
print(ventas_prod_t4.tail(), "\n")
# Out:
# Tienda 1 - Más vendidos:
# Producto
# Armario             60
# TV LED UHD 4K       60
# Microondas          60
# Secadora de ropa    58
# Mesa de noche       56
# Name: Producto, dtype: int64
#
# Tienda 1 - Menos vendidos:
# Producto
# Mochila                      39
# Pandereta                    36
# Olla de presión              35
# Celular ABXY                 33
# Auriculares con micrófono    33
# Name: Producto, dtype: int64
#
# Tienda 2 - Más vendidos:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Pandereta                    58
# Guitarra acústica            58
# Name: Producto, dtype: int64
#
# Tienda 2 - Menos vendidos:
# Producto
# Auriculares        37
# Sillón             35
# Impresora          34
# Mesa de comedor    34
# Juego de mesa      32
# Name: Producto, dtype: int64
#
# Tienda 3 - Más vendidos:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_t1 = tienda["Costo de envío"].mean()
envio_t2 = tienda2["Costo de envío"].mean()
envio_t3 = tienda3["Costo de envío"].mean()
envio_t4 = tienda4["Costo de envío"].mean()

# %%
print("Costo de envío promedio - Tienda 1:", round(envio_t1, 2))
print("Costo de envío promedio - Tienda 2:", round(envio_t2, 2))
print("Costo de envío promedio - Tienda 3:", round(envio_t3, 2))
print("Costo de envío promedio - Tienda 4:", round(envio_t4, 2))
# Out:
# Costo de envío promedio - Tienda 1: 26018.61
# Costo de envío promedio - Tienda 2: 25216.24
# Costo de envío promedio - Tienda 3: 24805.68
# Costo de envío promedio - Tienda 4: 23459.46

# %% [markdown]
# # Gráficos

# %%
import matplotlib.pyplot as plt

# Ingresos
plt.bar(ingresos.keys(), ingresos.values(), color=["blue","orange","green","red"])
plt.title("Ingresos totales por tienda")
plt.ylabel("Ingresos ($)")
plt.show()

# %%
import matplotlib.pyplot as plt

# Tomamos los top 5 de cada tienda
top5_t1 = ventas_prod_t1.head(5)
top5_t2 = ventas_prod_t2.head(5)
top5_t3 = ventas_prod_t3.head(5)
top5_t4 = ventas_prod_t4.head(5)

# Creamos un DataFrame unificado
top_productos = {
    "Tienda 1": top5_t1,
    "Tienda 2": top5_t2,
    "Tienda 3": top5_t3,
    "Tienda 4": top5_t4
}

# Configuramos la figura
plt.figure(figsize=(12,8))

# Graficamos cada tienda
for i, (tienda, data) in enumerate(top_productos.items()):
    plt.barh([f"{prod} ({tienda})" for prod in data.index], data.values, label=tienda)

# Personalización
plt.xlabel("Cantidad de ventas")
plt.title("Top 5 productos más vendidos por tienda")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos de cada tienda
tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
calificaciones = [calif_t1, calif_t2, calif_t3, calif_t4]
envios = [envio_t1, envio_t2, envio_t3, envio_t4]

# Gráfico de dispersión
plt.figure(figsize=(8,6))
plt.scatter(envios, calificaciones, s=150, c=["blue","orange","green","red"], alpha=0.7, edgecolor="k")

# Etiquetas para cada punto
for i, tienda in enumerate(tiendas):
    plt.text(envios[i]+0.05, calificaciones[i], tienda, fontsize=10, fontweight="bold")

plt.xlabel("Costo de envío promedio")
plt.ylabel("Calificación promedio")
plt.title("Relación: costo de envío vs calificación promedio")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %% [markdown]
# ## Resultados del análisis
#
# ### 1. Ingresos Totales por Tienda
# - **Tienda 1:** 1,150.88 millones
# - **Tienda 2:** 1,116.34 millones
# - **Tienda 3:** 1,098.02 millones
# - **Tienda 4:** 1,038.38 millones
#
#  *La Tienda 4 presenta los ingresos más bajos.*
#
#
#
# ### 2. Categorías más y menos vendidas
# - En todas las tiendas predominan **Muebles** y **Electrónicos** como líderes.
# - En la **Tienda 4**, categorías como **Instrumentos musicales y Libros** tienen menor participación.
#
#
#
# ### 3. Calificación promedio de clientes
# - **Tienda 1:** 3.98
# - **Tienda 2:** 4.04
# - **Tienda 3:** 4.05
# - **Tienda 4:** 4.00
#
#  Aunque la Tienda 4 tiene una calificación aceptable, **no destaca frente a las demás**.
#
#
#
# ### 4. Productos más y menos vendidos
# - **Tienda 4:** sus productos estrella incluyen **Cama box y Cubertería**, pero también presenta varios productos con bajas ventas (**Refrigerador, Guitarra eléctrica, Armario**).
# - Comparada con otras tiendas, sus “productos top” no generan la misma recurrencia que en Tienda 1 o Tienda 3.
#
#
#
# ### 5. Costos de envío promedio
# - **Tienda 1:** 26,018.61
# - **Tienda 2:** 25,216.24
# - **Tienda 3:** 24,805.68
# - **Tienda 4:** 23,459.46
#
#  La Tienda 4 es la más económica en envíos, pero este factor **no compensa sus menores ingresos y ventas**.
#
#
#
# ##  Conclusión y recomendación
#
# - **Tienda 1** lidera en ingresos y ventas, lo que la hace estratégica.
# - **Tienda 2 y Tienda 3** mantienen un buen equilibrio entre ingresos, calificación de clientes y ventas de productos.
# - **Tienda 4**, en cambio, presenta:
#   - El **menor nivel de ingresos totales**.
#   - Productos con **baja rotación**.
#   - Una calificación de clientes **que no la diferencia de las demás**.
#   - Aunque tiene costos de envío más bajos, esto no compensa su debilidad en ventas e ingresos.
#
#  **Recomendación final:**
# El Sr. Juan debería **dejar de vender en la Tienda 4** y destinar esos recursos a otro negocio más rentable.
# Las tiendas 1, 2 y 3 muestran mayor potencial para sostener la inversión y generar crecimiento a futuro.
